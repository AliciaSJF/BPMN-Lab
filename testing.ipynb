# %% [markdown]
# # Descripciones
#
# Vamos a usar 2 datasets:
# - [Camunda](https://github.com/camunda/bpmn-for-research/tree/master/BPMN%20for%20Research/English/01-Dispatch-of-goods): Dataset con descripciones del procesos y opciones de modelos, con la mejor versión según camunda. Se encuentran en la carpeta camunda
# - [SAP Signavio Academic Models](https://zenodo.org/records/7012043): Dataset con múltiples modelos de procesos. Las descripciones han sido creadas con diferentes llms en el cuadernillo descriptions_test y se encuentran en la carpeta signavio

# %% [markdown]
# # 🤖 ProMoAI

# %% [markdown]
# https://promoai.streamlit.app/
#
# Para probar ProMoAI vamos a utilizar su demo.

# %% [markdown]
# ## CAMUNDA

# %% [markdown]
# ### Ejemplo 1 : Dispatch of Goods
#
# **Desripción:**
#
# Please model the following process
# If goods shall be shipped, the secretary clarifies who will do the shipping. If you have large
# amounts, special shipping will be necessary. In these cases the secretary invites three logistic
# companies to make offers and she selects one of them. In case of small amounts, normal
# post shipment is used. Therefore a package label is written by the secretary and a parcel
# insurance taken by the logistics department head if necessary.
# In the meantime the goods can be already packaged by the warehousemen.
# If everything is ready, the packaged goods are prepared for being picked up by the logistic
# company.
# Background
# This process happens at a small hardware company that ships small amounts of goods to
# end customers but as well big amounts to other shops
#
# **BPMN esperado**
#
# ![image.png](attachment:image.png)
#
# **BPMN obtenido**
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# ---

# %% [markdown]
# ## Ejemplo 2: Signavio FarmInvest
#
# ### BPMN esperado:
#
# ![image-2.png](attachment:image-2.png)
#
# ### BPMN obtenido:
#
# ![image.png](attachment:image.png)
#
#
# ---

# %% [markdown]
# # MAO

# %% [markdown]
# https://anonymous.4open.science/r/MAO-1074/README.md
#
# 1. Crear un entorno virtual
# 2. Exportar api key
#    ```bash
#    $env:OPENAI_API_KEY="api_key"  # Windows
#    ```
#
#    ```bash
#    export OPENAI_API_KEY="api_key"
#    ```
# 3. Ejecutar MAO
#    ```bash
#    python run.py --task "Generar un modelo BPMN para un proceso de compra" --name "proceso_compra"
#    ```
# 4. a

# %% [markdown]
# ## Camunda
#
# ### Ejemplo 1: Dispatch of goods
#
#
# ```python
#
#    python run.py --task "Please model the following process
# If goods shall be shipped, the secretary clarifies who will do the shipping. If you have large
# amounts, special shipping will be necessary. In these cases the secretary invites three logistic
# companies to make offers and she selects one of them. In case of small amounts, normal
# post shipment is used. Therefore a package label is written by the secretary and a parcel
# insurance taken by the logistics department head if necessary.
# In the meantime the goods can be already packaged by the warehousemen.
# If everything is ready, the packaged goods are prepared for being picked up by the logistic
# company.
# Background
# This process happens at a small hardware company that ships small amounts of goods to
# end customers but as well big amounts to other shops" --name "Dispatch of Goods"
#
# ```
